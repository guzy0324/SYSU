# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=     1,  
                out_channels=   32,
                kernel_size=     7,
                stride=          1,
                padding=         3,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view((-1, 64 * 7 * 7))  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# <ipython-input-8-245f12972ba9>:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# <ipython-input-8-245f12972ba9>:66: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# ========== 20 ===== ===== test accuracy is  0.166 ==========
# ========== 40 ===== ===== test accuracy is  0.296 ==========
# ========== 60 ===== ===== test accuracy is  0.49 ==========
# ========== 80 ===== ===== test accuracy is  0.576 ==========
# ========== 100 ===== ===== test accuracy is  0.618 ==========
# ========== 120 ===== ===== test accuracy is  0.7 ==========
# ========== 140 ===== ===== test accuracy is  0.732 ==========
# ========== 160 ===== ===== test accuracy is  0.766 ==========
# ========== 180 ===== ===== test accuracy is  0.784 ==========
# ========== 200 ===== ===== test accuracy is  0.798 ==========
# ========== 220 ===== ===== test accuracy is  0.83 ==========
# ========== 240 ===== ===== test accuracy is  0.852 ==========
# ========== 260 ===== ===== test accuracy is  0.85 ==========
# ========== 280 ===== ===== test accuracy is  0.86 ==========
# ========== 300 ===== ===== test accuracy is  0.87 ==========
# ========== 320 ===== ===== test accuracy is  0.87 ==========
# ========== 340 ===== ===== test accuracy is  0.878 ==========
# ========== 360 ===== ===== test accuracy is  0.868 ==========
# ========== 380 ===== ===== test accuracy is  0.884 ==========
# ========== 400 ===== ===== test accuracy is  0.892 ==========
# ========== 420 ===== ===== test accuracy is  0.902 ==========
# ========== 440 ===== ===== test accuracy is  0.904 ==========
# ========== 460 ===== ===== test accuracy is  0.904 ==========
# ========== 480 ===== ===== test accuracy is  0.888 ==========
# ========== 500 ===== ===== test accuracy is  0.908 ==========
# ========== 520 ===== ===== test accuracy is  0.912 ==========
# ========== 540 ===== ===== test accuracy is  0.92 ==========
# ========== 560 ===== ===== test accuracy is  0.91 ==========
# ========== 580 ===== ===== test accuracy is  0.92 ==========
# ========== 600 ===== ===== test accuracy is  0.918 ==========
# ========== 620 ===== ===== test accuracy is  0.92 ==========
# ========== 640 ===== ===== test accuracy is  0.916 ==========
# ========== 660 ===== ===== test accuracy is  0.922 ==========
# ========== 680 ===== ===== test accuracy is  0.92 ==========
# ========== 700 ===== ===== test accuracy is  0.928 ==========
# ========== 720 ===== ===== test accuracy is  0.938 ==========
# ========== 740 ===== ===== test accuracy is  0.936 ==========
# ========== 760 ===== ===== test accuracy is  0.93 ==========
# ========== 780 ===== ===== test accuracy is  0.922 ==========
# ========== 800 ===== ===== test accuracy is  0.942 ==========
# ========== 820 ===== ===== test accuracy is  0.944 ==========
# ========== 840 ===== ===== test accuracy is  0.944 ==========
# ========== 860 ===== ===== test accuracy is  0.94 ==========
# ========== 880 ===== ===== test accuracy is  0.944 ==========
# ========== 900 ===== ===== test accuracy is  0.94 ==========
# ========== 920 ===== ===== test accuracy is  0.952 ==========
# ========== 940 ===== ===== test accuracy is  0.946 ==========
# ========== 960 ===== ===== test accuracy is  0.96 ==========
# ========== 980 ===== ===== test accuracy is  0.946 ==========
# ========== 1000 ===== ===== test accuracy is  0.948 ==========
# ========== 1020 ===== ===== test accuracy is  0.94 ==========
# ========== 1040 ===== ===== test accuracy is  0.948 ==========
# ========== 1060 ===== ===== test accuracy is  0.95 ==========
# ========== 1080 ===== ===== test accuracy is  0.948 ==========
# ========== 1100 ===== ===== test accuracy is  0.958 ==========
# ========== 1120 ===== ===== test accuracy is  0.948 ==========
# ========== 1140 ===== ===== test accuracy is  0.958 ==========
# ========== 1160 ===== ===== test accuracy is  0.948 ==========
# ========== 1180 ===== ===== test accuracy is  0.942 ==========
# ========== 20 ===== ===== test accuracy is  0.948 ==========
# ========== 40 ===== ===== test accuracy is  0.946 ==========
# ========== 60 ===== ===== test accuracy is  0.942 ==========
# ========== 80 ===== ===== test accuracy is  0.958 ==========
# ========== 100 ===== ===== test accuracy is  0.956 ==========
# ========== 120 ===== ===== test accuracy is  0.96 ==========
# ========== 140 ===== ===== test accuracy is  0.954 ==========
# ========== 160 ===== ===== test accuracy is  0.95 ==========
# ========== 180 ===== ===== test accuracy is  0.962 ==========
# ========== 200 ===== ===== test accuracy is  0.952 ==========
# ========== 220 ===== ===== test accuracy is  0.96 ==========
# ========== 240 ===== ===== test accuracy is  0.964 ==========
# ========== 260 ===== ===== test accuracy is  0.96 ==========
# ========== 280 ===== ===== test accuracy is  0.96 ==========
# ========== 300 ===== ===== test accuracy is  0.96 ==========
# ========== 320 ===== ===== test accuracy is  0.958 ==========
# ========== 340 ===== ===== test accuracy is  0.96 ==========
# ========== 360 ===== ===== test accuracy is  0.962 ==========
# ========== 380 ===== ===== test accuracy is  0.966 ==========
# ========== 400 ===== ===== test accuracy is  0.95 ==========
# ========== 420 ===== ===== test accuracy is  0.958 ==========
# ========== 440 ===== ===== test accuracy is  0.96 ==========
# ========== 460 ===== ===== test accuracy is  0.964 ==========
# ========== 480 ===== ===== test accuracy is  0.966 ==========
# ========== 500 ===== ===== test accuracy is  0.962 ==========
# ========== 520 ===== ===== test accuracy is  0.968 ==========
# ========== 540 ===== ===== test accuracy is  0.96 ==========
# ========== 560 ===== ===== test accuracy is  0.968 ==========
# ========== 580 ===== ===== test accuracy is  0.974 ==========
# ========== 600 ===== ===== test accuracy is  0.966 ==========
# ========== 620 ===== ===== test accuracy is  0.972 ==========
# ========== 640 ===== ===== test accuracy is  0.954 ==========
# ========== 660 ===== ===== test accuracy is  0.964 ==========
# ========== 680 ===== ===== test accuracy is  0.962 ==========
# ========== 700 ===== ===== test accuracy is  0.966 ==========
# ========== 720 ===== ===== test accuracy is  0.972 ==========
# ========== 740 ===== ===== test accuracy is  0.968 ==========
# ========== 760 ===== ===== test accuracy is  0.964 ==========
# ========== 780 ===== ===== test accuracy is  0.962 ==========
# ========== 800 ===== ===== test accuracy is  0.974 ==========
# ========== 820 ===== ===== test accuracy is  0.974 ==========
# ========== 840 ===== ===== test accuracy is  0.966 ==========
# ========== 860 ===== ===== test accuracy is  0.97 ==========
# ========== 880 ===== ===== test accuracy is  0.978 ==========
# ========== 900 ===== ===== test accuracy is  0.976 ==========
# ========== 920 ===== ===== test accuracy is  0.96 ==========
# ========== 940 ===== ===== test accuracy is  0.972 ==========
# ========== 960 ===== ===== test accuracy is  0.968 ==========
# ========== 980 ===== ===== test accuracy is  0.978 ==========
# ========== 1000 ===== ===== test accuracy is  0.954 ==========
# ========== 1020 ===== ===== test accuracy is  0.962 ==========
# ========== 1040 ===== ===== test accuracy is  0.974 ==========
# ========== 1060 ===== ===== test accuracy is  0.976 ==========
# ========== 1080 ===== ===== test accuracy is  0.966 ==========
# ========== 1100 ===== ===== test accuracy is  0.974 ==========
# ========== 1120 ===== ===== test accuracy is  0.968 ==========
# ========== 1140 ===== ===== test accuracy is  0.978 ==========
# ========== 1160 ===== ===== test accuracy is  0.97 ==========
# ========== 1180 ===== ===== test accuracy is  0.982 ==========
# ========== 20 ===== ===== test accuracy is  0.974 ==========
# ========== 40 ===== ===== test accuracy is  0.978 ==========
# ========== 60 ===== ===== test accuracy is  0.974 ==========
# ========== 80 ===== ===== test accuracy is  0.962 ==========
# ========== 100 ===== ===== test accuracy is  0.968 ==========
# ========== 120 ===== ===== test accuracy is  0.972 ==========
# ========== 140 ===== ===== test accuracy is  0.978 ==========
# ========== 160 ===== ===== test accuracy is  0.976 ==========
# ========== 180 ===== ===== test accuracy is  0.968 ==========
# ========== 200 ===== ===== test accuracy is  0.976 ==========
# ========== 220 ===== ===== test accuracy is  0.976 ==========
# ========== 240 ===== ===== test accuracy is  0.972 ==========
# ========== 260 ===== ===== test accuracy is  0.972 ==========
# ========== 280 ===== ===== test accuracy is  0.98 ==========
# ========== 300 ===== ===== test accuracy is  0.968 ==========
# ========== 320 ===== ===== test accuracy is  0.972 ==========
# ========== 340 ===== ===== test accuracy is  0.974 ==========
# ========== 360 ===== ===== test accuracy is  0.974 ==========
# ========== 380 ===== ===== test accuracy is  0.972 ==========
# ========== 400 ===== ===== test accuracy is  0.98 ==========
# ========== 420 ===== ===== test accuracy is  0.972 ==========
# ========== 440 ===== ===== test accuracy is  0.982 ==========
# ========== 460 ===== ===== test accuracy is  0.98 ==========
# ========== 480 ===== ===== test accuracy is  0.976 ==========
# ========== 500 ===== ===== test accuracy is  0.98 ==========
# ========== 520 ===== ===== test accuracy is  0.972 ==========
# ========== 540 ===== ===== test accuracy is  0.974 ==========
# ========== 560 ===== ===== test accuracy is  0.976 ==========
# ========== 580 ===== ===== test accuracy is  0.982 ==========
# ========== 600 ===== ===== test accuracy is  0.984 ==========
# ========== 620 ===== ===== test accuracy is  0.984 ==========
# ========== 640 ===== ===== test accuracy is  0.974 ==========
# ========== 660 ===== ===== test accuracy is  0.972 ==========
# ========== 680 ===== ===== test accuracy is  0.974 ==========
# ========== 700 ===== ===== test accuracy is  0.976 ==========
# ========== 720 ===== ===== test accuracy is  0.968 ==========
# ========== 740 ===== ===== test accuracy is  0.974 ==========
# ========== 760 ===== ===== test accuracy is  0.972 ==========
# ========== 780 ===== ===== test accuracy is  0.972 ==========
# ========== 800 ===== ===== test accuracy is  0.968 ==========
# ========== 820 ===== ===== test accuracy is  0.988 ==========
# ========== 840 ===== ===== test accuracy is  0.98 ==========
# ========== 860 ===== ===== test accuracy is  0.972 ==========
# ========== 880 ===== ===== test accuracy is  0.982 ==========
# ========== 900 ===== ===== test accuracy is  0.976 ==========
# ========== 920 ===== ===== test accuracy is  0.974 ==========
# ========== 940 ===== ===== test accuracy is  0.976 ==========
# ========== 960 ===== ===== test accuracy is  0.976 ==========
# ========== 980 ===== ===== test accuracy is  0.974 ==========
# ========== 1000 ===== ===== test accuracy is  0.972 ==========
# ========== 1020 ===== ===== test accuracy is  0.972 ==========
# ========== 1040 ===== ===== test accuracy is  0.978 ==========
# ========== 1060 ===== ===== test accuracy is  0.976 ==========
# ========== 1080 ===== ===== test accuracy is  0.974 ==========
# ========== 1100 ===== ===== test accuracy is  0.976 ==========
# ========== 1120 ===== ===== test accuracy is  0.98 ==========
# ========== 1140 ===== ===== test accuracy is  0.982 ==========
# ========== 1160 ===== ===== test accuracy is  0.968 ==========
# ========== 1180 ===== ===== test accuracy is  0.98 ==========
